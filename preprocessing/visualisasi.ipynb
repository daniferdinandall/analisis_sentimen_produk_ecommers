# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
df = pd.read_csv('../Dataset/dataset_2.csv')

# %%
# Menghitung jumlah masing-masing label
sentiment_counts = df['Label'].value_counts()

# %%
plt.figure(figsize=(8, 8))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.show()

# %%
# Bar Chart
plt.figure(figsize=(10, 6))
sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values, palette='viridis')
plt.title('Jumlah Ulasan per Sentimen')
plt.xlabel('Sentimen')
plt.ylabel('Jumlah Ulasan')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12952\4105630232.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values, palette='viridis')

# %%
# Membuat Word Cloud untuk setiap sentimen
for sentiment in data['Label'].unique():
    # Filter teks ulasan berdasarkan sentimen
    text = ' '.join(data[data['Label'] == sentiment]['Ulasan'])
    
    # Membuat Word Cloud
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    
    # Menampilkan Word Cloud
    plt.figure(figsize=(15, 8))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f'Word Cloud untuk Ulasan: {sentiment}')
    plt.show()
